# %% [markdown]
# <a href="https://colab.research.google.com/github/Timixojo/Timixojo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import pandas and load California training datasets

import pandas as pd

df_train=pd.read_csv('/content/sample_data/california_housing_train (1).csv')

df_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
#load California testing datasets

df_test=pd.read_csv('/content/sample_data/california_housing_test.csv')

df_test
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
#Define the data for x_train, y_train, datasets

x_train=df_train.loc[:,['housing_median_age', 'total_rooms','total_bedrooms','population', 'households','median_income' ]]
y_train=df_train.loc[:,['median_house_value']]

x_train

#y_train
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    15.0       5612.0          1283.0      1015.0
# 1                    19.0       7650.0          1901.0      1129.0
# 2                    17.0        720.0           174.0       333.0
# 3                    14.0       1501.0           337.0       515.0
# 4                    20.0       1454.0           326.0       624.0
# ...                   ...          ...             ...         ...
# 16995                52.0       2217.0           394.0       907.0
# 16996                36.0       2349.0           528.0      1194.0
# 16997                17.0       2677.0           531.0      1244.0
# 16998                19.0       2672.0           552.0      1298.0
# 16999                52.0       1820.0           300.0       806.0
#
#        households  median_income
# 0           472.0         1.4936
# 1           463.0         1.8200
# 2           117.0         1.6509
# ...

# %%
#Define the data for x_test, y_test, datasets

x_test=df_test.loc[:,['housing_median_age', 'total_rooms','total_bedrooms','population', 'households','median_income' ]]
y_test=df_test.loc[:,['median_house_value' ]]

x_test

#y_test
# Out:
#       housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0                   27.0       3885.0           661.0      1537.0       606.0
# 1                   43.0       1510.0           310.0       809.0       277.0
# 2                   27.0       3589.0           507.0      1484.0       495.0
# 3                   28.0         67.0            15.0        49.0        11.0
# 4                   19.0       1241.0           244.0       850.0       237.0
# ...                  ...          ...             ...         ...         ...
# 2995                23.0       1450.0           642.0      1258.0       607.0
# 2996                27.0       5257.0          1082.0      3496.0      1036.0
# 2997                10.0        956.0           201.0       693.0       220.0
# 2998                40.0         96.0            14.0        46.0        14.0
# 2999                42.0       1765.0           263.0       753.0       260.0
#
#       median_income
# ...

# %%
#Implementing Decision Tree Regression

#Train DT model

from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
#Use the created model to predict the test data

y_predict = model.predict(x_test)

y_predict
# Out:
# array([287800., 109500., 307100., ..., 114600., 137500., 500001.])

# %%
#Evaluation metrics to test the model

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  9269965544.980333
# Mean Absolute Error:  68127.347
# Root Mean Squared Error:  96280.6602853363

# %%
#Train the Random Forest model

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
#Use the created model to predict the test data.

y_predict = model.predict(x_test)

y_predict
# Out:
# array([381142.13, 153933.  , 288551.01, ..., 102487.  , 152351.06,
#        485906.81])

# %%
#Evaluation metrics to test the model

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.root_mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  4574220670.791489
# Mean Absolute Error:  48372.66734
# Root Mean Squared Error:  260.06342510953783
